# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
img= mpl.image.imread('/content/known face.jpg')
img
# Out:
# array([[[140, 142, 139],
#         [141, 143, 140],
#         [140, 142, 139],
#         ...,
#         [147, 147, 145],
#         [148, 148, 146],
#         [149, 149, 147]],
#
#        [[138, 140, 137],
#         [139, 141, 138],
#         [139, 141, 138],
#         ...,
#         [147, 147, 145],
#         [148, 148, 146],
#         [148, 148, 146]],
#
#        [[138, 140, 137],
#         [138, 140, 137],
#         [139, 141, 138],
#         ...,
#         [148, 148, 146],
#         [148, 148, 146],
#         [148, 148, 146]],
#
#        ...,
#
#        [[158, 160, 157],
#         [158, 160, 157],
#         [158, 160, 157],
#         ...,
#         [164, 166, 163],
#         [163, 165, 162],
#         [163, 165, 162]],
#
#        [[159, 161, 158],
#         [158, 160, 157],
#         [159, 161, 158],
#         ...,
#         [164, 166, 163],
#         [164, 166, 163],
#         [163, 165, 162]],
#
#        [[160, 162, 159],
#         [159, 161, 158],
#         [159, 161, 158],
#         ...,
#         [164, 166, 163],
#         [164, 166, 163],
#         [163, 165, 162]]], dtype=uint8)

# %%
img.shape
# Out:
# (1280, 959, 3)

# %%
x=img.reshape(-1,3)
x.shape
# Out:
# (1227520, 3)

# %%
kmeans=KMeans(n_clusters=10,n_init=10)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=10, n_init=10)

# %%
seg_img = kmeans.cluster_centers_[kmeans.labels_]
seg_img = seg_img.reshape(img.shape)

# %%
plt.imshow(seg_img/255)
