# %%
# K means , we have to tell no of clusters.
# elbow is ambigous

# k means is very very senstive, centiord based

# what if weird shape given , it will cry
#like curve

# %%
# density based clustering
# make cluster within radius of epslion

# %%
# Density Based Spatial clustering of Application with Noise

# %%
# take a point and radius with ep if the data opints > minpts(points)  , that point is called dense else sparse

# %%
# Points !-core, 2-border, 3- noise

# %%
# density conneccted points

# %%
# A and B points are indriectly connected with some core points if the distance b/w core points <= ep then they are connected and same cluster else two different cluster(also there is nosie point b/w them).

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([[1,2],[2,2],[2,3],[8,7],[25,80]])

# %%
plt.scatter(x[:,0] ,x[:,1])

# %%
db=DBSCAN(eps=3,min_samples=2)
db.fit(x)
db.labels_
# Out:
# array([ 0,  0,  0, -1, -1])

# %%
from sklearn.datasets import make_circles

# %%
x,_=make_circles(n_samples=500, factor=.5, noise=.03, random_state=4)

# %%
dbscan=DBSCAN(eps=0.1,min_samples=5)
clusters=dbscan.fit_predict(x)

# %%
plt.scatter(x[:,0],x[:,1],c=clusters,cmap='viridis',marker='o')
plt.title("DBSCAN of Concentric circles")
plt.xlabel("feature 0")
plt.ylabel("feature 1")
plt.show()
