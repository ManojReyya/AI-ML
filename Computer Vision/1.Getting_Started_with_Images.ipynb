# %% [markdown]
# ##Getting Started with Images
#
# 1.Reading an image
#
# 2.Check image attributes like datatype and shape
#
# 3.Matrix representation of an image in Numpy
#
# 4.Color Images and splitting/merging image channels
#
# 5.Displaying images using matplotlib
#
# 6."Saving images

# %%
#import libraries

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# %matplotlib inline

# %% [markdown]
# ##Reading an Image

# %%
Image(filename="/content/download.jpg")

# %% [markdown]
# ##2.Check image attributes like datatype and shape

# %%
# print the size  of image
print("Image size (H, W) is:", app_img.shape)

# print data-type of image
print("Data type of image is:", app_img.dtype)
# Out:
# Image size (H, W) is: (174, 290)
# Data type of image is: uint8

# %% [markdown]
# ##3.Matrix representation of an image in Numpy

# %%
# Read image as gray scale.
pix_img = cv2.imread("/content/download.jpg", 0)

# Print the image data (pixel values), element of a 2D numpy array.
# Each pixel value is 8-bits [0,255]
print(pix_img)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %% [markdown]
# ##4.Color Images and splitting/merging image channels

# %%
# Split the image into the B,G,R components
img_NZ_bgr = cv2.imread("/content/download.jpg", cv2.IMREAD_COLOR)
b, g, r = cv2.split(img_NZ_bgr)

# Show the channels
plt.figure(figsize=[20, 5])

plt.subplot(141);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

# Merge the individual channels into a BGR image
imgMerged = cv2.merge((b, g, r))
# Show the merged output
plt.subplot(144)
plt.imshow(imgMerged[:, :, ::-1])
plt.title("Merged Output")
# Out:
# Text(0.5, 1.0, 'Merged Output')

# %%
#OpenCV is often referred to as RGB but it is actually BGR (the bytes are reversed)

# %%
img_NZ_rgb = cv2.cvtColor(img_NZ_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_NZ_rgb)

# %%
img_hsv = cv2.cvtColor(img_NZ_bgr, cv2.COLOR_BGR2HSV)

# Split the image into the B,G,R components
h,s,v = cv2.split(img_hsv) #hue, saturation, and value

# Show the channels
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(h, cmap="gray");plt.title("H Channel");
plt.subplot(142);plt.imshow(s, cmap="gray");plt.title("S Channel");
plt.subplot(143);plt.imshow(v, cmap="gray");plt.title("V Channel");
plt.subplot(144);plt.imshow(img_NZ_rgb);   plt.title("Original");

# %%
#modifying individual channel
h_new = h + 10
img_NZ_merged = cv2.merge((h_new, s, v))
img_NZ_rgb = cv2.cvtColor(img_NZ_merged, cv2.COLOR_HSV2RGB)

# Show the channels
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(h, cmap="gray");plt.title("H Channel");
plt.subplot(142);plt.imshow(s, cmap="gray");plt.title("S Channel");
plt.subplot(143);plt.imshow(v, cmap="gray");plt.title("V Channel");
plt.subplot(144);plt.imshow(img_NZ_rgb);   plt.title("Original");

# %% [markdown]
# ##5.Displaying images using matplotlib

# %%
plt.imshow(pix_img)
#  What happened?

# %% [markdown]
# ##6."Saving images

# %%
# save the image
cv2.imwrite("apples.png", img_NZ_bgr)

Image(filename='apples.png')

# %%
# read the image as Color
img_NZ_bgr = cv2.imread("apples.png", cv2.IMREAD_COLOR)
print("img_NZ_bgr shape (H, W, C) is:", img_NZ_bgr.shape)

# read the image as Grayscaled
img_NZ_gry = cv2.imread("apples.png", cv2.IMREAD_GRAYSCALE)
print("img_NZ_gry shape (H, W) is:", img_NZ_gry.shape)
# Out:
# img_NZ_bgr shape (H, W, C) is: (174, 290, 3)
# img_NZ_gry shape (H, W) is: (174, 290)
