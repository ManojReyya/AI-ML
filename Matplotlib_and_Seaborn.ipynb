# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %% [markdown]
# ##Line Chart

# %%
x=[1,2,3,4,5,6,7,8,9]
y=[2,1,4,3,8,5,7,0,1]

# %%
plt.plot(x,y)

# %%
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=x,y=y)
# Out:
# <Axes: >

# %% [markdown]
# ##Pie Chart

# %%
data=[10,25,30,35]
plt.pie(data)
# Out:
# ([<matplotlib.patches.Wedge at 0x77fe9058f3a0>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(0.1720779013721078, 1.086457176265761, ''),
#   Text(-1.0999999999999988, -5.149471622296949e-08, ''),
#   Text(0.4993896139484798, -0.9801071438778459, '')])

# %%
data=[10,25,30,35]
plt.pie(data)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
data=[10,25,30,35]
plt.pie(data,[0.2,0,0,0],labels=['r1','r2','r3','r4'],autopct="%1.1f%%",shadow = True,colors=["red","green","blue","purple"])
plt.title("Pie chart")
plt.show()

# %% [markdown]
# ##Bar Plot

# %%
x=[1,2,3,4,5,6,7,8,9]
y=[2,1,4,3,8,5,7,0,1]

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 0., 1., 1., 1., 1., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.histplot(x)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
df=pd.read_csv('/content/mtcars.csv')
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.hp.plot()
# Out:
# <Axes: >

# %%
df.mpg.plot()
# Out:
# <Axes: >

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.mpg.plot()
df.hp.plot()
plt.legend(['Miles per gallon','Horse power'])

# %%
sns.distplot(df.mpg)
# Out:
# <ipython-input-29-484459c5141a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.mpg)
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
sns.displot(df.mpg)

# %% [markdown]
# ##Subplot

# %%
(0,0) (0,1)
(1,0) (1,1)

# %%
from matplotlib import rcParams

# %%
rcParams['figure.figsize']=8,8

# %%
fig,ax=plt.subplots(2,2)
ax[0,0].plot(x,y)
ax[0,1].pie(data)
ax[1,0].bar(x,y)
ax[1,1].scatter(x,y)

# %%
sns.boxplot(df.mpg)
# Out:
# <Axes: ylabel='mpg'>

# %%
sns.get_dataset_names()  #sns is better than mathplot because it as some datasets and more options
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.petal_length.unique()
# Out:
# array([1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1. , 1.9, 4.7, 4.5, 4.9, 4. ,
#        4.6, 3.3, 3.9, 3.5, 4.2, 3.6, 4.4, 4.1, 4.8, 4.3, 5. , 3.8, 3.7,
#        5.1, 3. , 6. , 5.9, 5.6, 5.8, 6.6, 6.3, 6.1, 5.3, 5.5, 6.7, 6.9,
#        5.7, 6.4, 5.4, 5.2])

# %%
iris.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ##Jointplot

# %%
# three types of visualization
# uniary visualization-one feature
# binary visualization-two features
# multi-varent visualization-multiple features

# %%
 #jointplot is a binay visualization

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris)

# %% [markdown]
# ##Pairplot- multi-varent visualization

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='sepal_width',kind='scatter',diag_kind='kde')

# %%
sns.pairplot(iris,hue='sepal_width',kind='scatter',diag_kind='hist')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris1=iris.drop(columns=['species'],axis=1)

# %%
iris1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris1.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ##Heatmap = correlation graph

# %%
sns.heatmap(iris1.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(iris1.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(iris1.corr(),annot=True,cmap="crest")
# Out:
# <Axes: >

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
